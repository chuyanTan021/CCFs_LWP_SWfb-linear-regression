# %%
import xarray as xr
import PyNIO as Nio # deprecated
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker   #..important for gridlinrs
import cartopy.crs as ccrs   #..projection method
import cartopy.feature as cfeat
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter   #..x,y --> lon, lat

# %%
# Calculate 5*5 bin array for variables (LWP, CCFs) in Sounthern Ocean Region:
#..set area-mean range and define function
s_range = np.arange(-90., 90., 5.) + 2.5  #..global-region latitude edge:  36
x_range = np.arange(-180., 180., 5.)  #..logitude sequences edge: number: 72
y_range = np.arange(-85, -40., 5.) + 2.5  #..southern-ocaen latitude edge: 9

#.. current model #: 18 + 12 (except: '19')
path_data = '/glade/work/chuyan/Research/Cloud_CCFs_RMs/Tan_et_al_2023_JGR-A__/data_file/'
path_plot = '/glade/work/chuyan/Research/Cloud_CCFs_RMs/Tan_et_al_2023_JGR-A__/plot_file/'

# %%
# Read ERA-5 data:

f5 = xr.open_dataset('era5_monthly_averaged_2019_uv.grib', engine = 'pynio')
f6 = xr.open_dataset('era5_monthly_averaged_2019.grib', engine = 'pynio')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<function open_file at 0x2ad54ef23ef0>, ('/glade/work/chuyan/Research/Cloud_CCFs_RMs/Tan_et_al_2023_JGR-A__/era5_monthly_averaged_2019_uv.grib',), 'r', ()]
#
# During handling of the above exception, another exception occurred:
#
# NIOError                                  Traceback (most recent call last)
# <ipython-input-4-8d94f75c2d4b> in <module>
#       1 # Read ERA-5 data:
#       2
# ----> 3 f5 = xr.open_dataset('era5_monthly_averaged_2019_uv.grib', engine = 'pynio')
#       4 f6 = xr.open_dataset('era5_monthly_averaged_2019.grib', engine = 'pynio')
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     570
#     571         opener = _get_backend_cls(engine)
# --> 572         store = opener(filename_or_obj, **extra_kwargs, **backend_kwargs)
#     573
#     574     with close_on_error(store):
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/pynio_.py in __init__(self, filename, mode, lock, **kwargs)
#      55         # xarray provides its own support for FillValue,
#      56         # so turn off PyNIO's support for the same.
# ---> 57         self.ds.set_option("MaskedArrayMode", "MaskedNever")
#      58
#      59     @property
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/pynio_.py in ds(self)
#      59     @property
#      60     def ds(self):
# ---> 61         return self._manager.acquire()
#      62
#      63     def open_store_variable(self, name, var):
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/file_manager.py in acquire(self, needs_lock)
#     179             An open file object, as returned by ``opener(*args, **kwargs)``.
#     180         """
# --> 181         file, _ = self._acquire_with_cache_info(needs_lock)
#     182         return file
#     183
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# /glade/u/ssg/ch/usr/jupyterhub/envs/npl-3.7.9/dav/lib/python3.7/site-packages/PyNIO/Nio.py in open_file(filename, mode, options, history, format)
#     749     mask_above_value = _get_option_value(options,_nio.option_defaults,'MaskAboveValue')
#     750
# --> 751     file = _nio.open_file(filename,mode,options,history,format)
#     752
#     753     file_proxy = _proxy(file, 'str', __del__=__del__,create_variable=create_variable,create_group=create_group,close=close)
#
# NIOError: Unable to open file

# %%
tar -xzf  eccodes-x.y.z-Source.tar.gz
> mkdir build ; cd build
 
> cmake -DCMAKE_INSTALL_PREFIX=/path/to/where/you/install/eccodes ../eccodes-x.y.z-Source
...
 
> make
> ctest
> make install

# %%
# !conda install -c conda-forge pynio
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /ncar/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20220511
#
#   added / updated specs:
#     - pynio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.3               |       hafa529b_0          39 KB  conda-forge
#     boost-cpp-1.78.0           |       h75c5d50_1        17.1 MB  conda-forge
#     cairo-1.16.0               |    ha61ee94_1014         1.5 MB  conda-forge
#     cfitsio-4.2.0              |       hd9d235c_0         828 KB  conda-forge
#     conda-23.1.0               |   py39hf3d152e_0         906 KB  conda-forge
#     cryptography-38.0.4        |   py39h3ccb8fc_0         1.3 MB  conda-forge
#     curl-7.88.1                |       hdc1c0ab_0          86 KB  conda-forge
#     expat-2.5.0                |       h27087fc_0         189 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freeglut-3.2.2             |       h9c3ff4c_1         162 KB  conda-forge
#     freetype-2.12.1            |       hca18f0e_1         611 KB  conda-forge
#     freexl-1.0.6               |       h166bdaf_1          48 KB  conda-forge
#     g2clib-1.6.0               |                3          42 KB  conda-forge
#     geos-3.11.1                |       h27087fc_0         1.6 MB  conda-forge
#     geotiff-1.7.1              |       h7157cca_5         249 KB  conda-forge
#     gettext-0.21.1             |       h27087fc_0         4.1 MB  conda-forge
#     glib-2.74.1                |       h6239696_1         474 KB  conda-forge
#     glib-tools-2.74.1          |       h6239696_1         107 KB  conda-forge
#     hdf4-4.2.15                |       h9772cbc_5         951 KB  conda-forge
#     hdf5-1.12.2                |nompi_h4df4325_101         3.2 MB  conda-forge
#     hdfeos2-2.20               |    hb955811_1002         227 KB  conda-forge
#     hdfeos5-5.1.16             |      hc2f950b_10         562 KB  conda-forge
#     jasper-2.0.33              |       h0ff4b12_1         709 KB  conda-forge
#     json-c-0.16                |       hc379101_0         275 KB  conda-forge
#     kealib-1.5.0               |       ha7026e8_0         160 KB  conda-forge
#     krb5-1.20.1                |       h81ceb04_0         1.3 MB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libaec-1.0.6               |       hcb278e6_1          34 KB  conda-forge
#     libcurl-7.88.1             |       hdc1c0ab_0         350 KB  conda-forge
#     libdap4-3.20.6             |       hd7c4107_2        11.3 MB  conda-forge
#     libdeflate-1.14            |       h166bdaf_0          81 KB  conda-forge
#     libgcc-ng-12.2.0           |      h65d4601_19         931 KB  conda-forge
#     libgdal-3.5.3              |      h05f8703_11        12.0 MB  conda-forge
#     libglib-2.74.1             |       h606061b_1         3.1 MB  conda-forge
#     libglu-9.0.0               |    he1b5a44_1001         413 KB  conda-forge
#     libgomp-12.2.0             |      h65d4601_19         455 KB  conda-forge
#     libiconv-1.17              |       h166bdaf_0         1.4 MB  conda-forge
#     libkml-1.3.0               |    h37653c0_1015         610 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_h261ec11_106         1.5 MB  conda-forge
#     libnghttp2-1.52.0          |       h61bc06f_0         608 KB  conda-forge
#     libpng-1.6.39              |       h753d276_0         276 KB  conda-forge
#     libpq-15.2                 |       hb675445_0         2.3 MB  conda-forge
#     librttopo-1.1.0            |      ha49c73b_12         236 KB  conda-forge
#     libspatialite-5.0.1        |      h7c8129e_22         4.4 MB  conda-forge
#     libsqlite-3.40.0           |       h753d276_0         791 KB  conda-forge
#     libssh2-1.10.0             |       hf14f497_3         234 KB  conda-forge
#     libstdcxx-ng-12.2.0        |      h46fd767_19         4.3 MB  conda-forge
#     libtiff-4.5.0              |       h82bc61c_0         398 KB  conda-forge
#     libwebp-1.2.4              |       h1daa5a0_1          82 KB  conda-forge
#     libwebp-base-1.2.4         |       h5eee18b_1         376 KB
#     libxml2-2.10.3             |       h7463322_0         754 KB  conda-forge
#     libzip-1.9.2               |       hc929e4a_1          97 KB  conda-forge
#     libzlib-1.2.13             |       h166bdaf_4          64 KB  conda-forge
#     nodejs-17.9.0              |       h8839609_0        15.2 MB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     nss-3.89                   |       he45b914_0         1.9 MB  conda-forge
#     openjpeg-2.5.0             |       hfec8fc6_2         344 KB  conda-forge
#     openssl-3.1.0              |       h0b41bf4_0         2.5 MB  conda-forge
#     pcre2-10.40                |       hc3806b6_0         2.3 MB  conda-forge
#     pillow-9.4.0               |   py39h6a678d5_0         727 KB
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     poppler-22.12.0            |       h381b16e_0        17.3 MB
#     poppler-data-0.4.12        |       hd8ed1ab_0         2.2 MB  conda-forge
#     postgresql-15.2            |       h3248436_0         4.9 MB  conda-forge
#     proj-9.1.0                 |       h8ffa02c_1         2.7 MB  conda-forge
#     pycurl-7.45.1              |   py39h9297c8b_3          74 KB  conda-forge
#     pynio-1.5.5                |  py39h91e556f_19         5.6 MB  conda-forge
#     python-3.9.16              |h2782a2a_0_cpython        23.0 MB  conda-forge
#     readline-8.1.2             |       h0f457ee_0         291 KB  conda-forge
#     snappy-1.1.10              |       h9fff704_0          38 KB  conda-forge
#     tiledb-2.13.2              |       hd532e3d_0         4.9 MB  conda-forge
#     tzcode-2022g               |       h166bdaf_0          65 KB  conda-forge
#     xerces-c-3.2.4             |       h55805fa_1         1.7 MB  conda-forge
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-inputproto-2.3.2      |    h7f98852_1002          19 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.8.4          |       h0b41bf4_0         810 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxi-1.7.10          |       h7f98852_0          46 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h0b41bf4_1003          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     zlib-1.2.13                |       h166bdaf_4          92 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       175.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   blosc              conda-forge/linux-64::blosc-1.21.3-hafa529b_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.78.0-h75c5d50_1
#   cairo              conda-forge/linux-64::cairo-1.16.0-ha61ee94_1014
#   cfitsio            conda-forge/linux-64::cfitsio-4.2.0-hd9d235c_0
#   expat              conda-forge/linux-64::expat-2.5.0-h27087fc_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freeglut           conda-forge/linux-64::freeglut-3.2.2-h9c3ff4c_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h166bdaf_1
#   g2clib             conda-forge/linux-64::g2clib-1.6.0-3
#   geos               conda-forge/linux-64::geos-3.11.1-h27087fc_0
#   geotiff            conda-forge/linux-64::geotiff-1.7.1-h7157cca_5
#   glib               conda-forge/linux-64::glib-2.74.1-h6239696_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.74.1-h6239696_1
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h9772cbc_5
#   hdf5               conda-forge/linux-64::hdf5-1.12.2-nompi_h4df4325_101
#   hdfeos2            conda-forge/linux-64::hdfeos2-2.20-hb955811_1002
#   hdfeos5            conda-forge/linux-64::hdfeos5-5.1.16-hc2f950b_10
#   jasper             conda-forge/linux-64::jasper-2.0.33-h0ff4b12_1
#   json-c             conda-forge/linux-64::json-c-0.16-hc379101_0
#   kealib             conda-forge/linux-64::kealib-1.5.0-ha7026e8_0
#   libaec             conda-forge/linux-64::libaec-1.0.6-hcb278e6_1
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_2
#   libgdal            conda-forge/linux-64::libgdal-3.5.3-h05f8703_11
#   libglu             conda-forge/linux-64::libglu-9.0.0-he1b5a44_1001
#   libkml             conda-forge/linux-64::libkml-1.3.0-h37653c0_1015
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_h261ec11_106
#   libpq              conda-forge/linux-64::libpq-15.2-hb675445_0
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-ha49c73b_12
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h7c8129e_22
#   libsqlite          conda-forge/linux-64::libsqlite-3.40.0-h753d276_0
#   libxml2            conda-forge/linux-64::libxml2-2.10.3-h7463322_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc929e4a_1
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.89-he45b914_0
#   pcre2              conda-forge/linux-64::pcre2-10.40-hc3806b6_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   poppler            pkgs/main/linux-64::poppler-22.12.0-h381b16e_0
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-15.2-h3248436_0
#   proj               conda-forge/linux-64::proj-9.1.0-h8ffa02c_1
#   pynio              conda-forge/linux-64::pynio-1.5.5-py39h91e556f_19
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   tiledb             conda-forge/linux-64::tiledb-2.13.2-hd532e3d_0
#   tzcode             conda-forge/linux-64::tzcode-2022g-h166bdaf_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.4-h55805fa_1
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-inputproto    conda-forge/linux-64::xorg-inputproto-2.3.2-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h0b41bf4_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.7.10-h7f98852_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
# The following packages will be UPDATED:
#
#   conda                              22.11.1-py39hf3d152e_1 --> 23.1.0-py39hf3d152e_0
#   cryptography                        36.0.2-py39hd97740a_1 --> 38.0.4-py39h3ccb8fc_0
#   curl                                    7.83.1-h7bff187_0 --> 7.88.1-hdc1c0ab_0
#   freetype                                2.10.4-h0708190_1 --> 2.12.1-hca18f0e_1
#   gettext                            0.19.8.1-h73d1719_1008 --> 0.21.1-h27087fc_0
#   krb5                                    1.19.3-h3790be6_0 --> 1.20.1-h81ceb04_0
#   lerc                                       3.0-h9c3ff4c_0 --> 4.0.0-h27087fc_0
#   libcurl                                 7.83.1-h7bff187_0 --> 7.88.1-hdc1c0ab_0
#   libdeflate                                1.10-h7f98852_0 --> 1.14-h166bdaf_0
#   libgcc-ng                              11.2.0-h1d223b6_16 --> 12.2.0-h65d4601_19
#   libglib                                 2.70.2-h174f98d_4 --> 2.74.1-h606061b_1
#   libgomp                                11.2.0-h1d223b6_16 --> 12.2.0-h65d4601_19
#   libiconv                                  1.16-h516909a_0 --> 1.17-h166bdaf_0
#   libnghttp2                              1.47.0-h727a467_0 --> 1.52.0-h61bc06f_0
#   libpng                                  1.6.37-h21135ba_2 --> 1.6.39-h753d276_0
#   libssh2                                 1.10.0-ha56f1ee_2 --> 1.10.0-hf14f497_3
#   libstdcxx-ng                           11.2.0-he4da1e4_16 --> 12.2.0-h46fd767_19
#   libtiff                                  4.3.0-h542a066_3 --> 4.5.0-h82bc61c_0
#   libwebp                                  1.2.2-h3452ae3_0 --> 1.2.4-h1daa5a0_1
#   libwebp-base       conda-forge::libwebp-base-1.2.2-h7f98~ --> pkgs/main::libwebp-base-1.2.4-h5eee18b_1
#   libzlib                              1.2.11-h166bdaf_1014 --> 1.2.13-h166bdaf_4
#   openjpeg                                 2.4.0-hb52868f_1 --> 2.5.0-hfec8fc6_2
#   openssl                                 1.1.1o-h166bdaf_0 --> 3.1.0-h0b41bf4_0
#   pillow             conda-forge::pillow-9.1.0-py39hae2aec~ --> pkgs/main::pillow-9.4.0-py39h6a678d5_0
#   pycurl                              7.45.1-py39hd73adbb_1 --> 7.45.1-py39h9297c8b_3
#   python                          3.9.12-h9a8a25e_1_cpython --> 3.9.16-h2782a2a_0_cpython
#   readline                                   8.1-h46c0cb4_0 --> 8.1.2-h0f457ee_0
#   xz                                       5.2.5-h516909a_1 --> 5.2.6-h166bdaf_0
#   zlib                                 1.2.11-h166bdaf_1014 --> 1.2.13-h166bdaf_4
#
# The following packages will be DOWNGRADED:
#
#   nodejs                                  17.9.0-h96d913c_0 --> 17.9.0-h8839609_0
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
# !Y
# Out:
# /bin/bash: Y: command not found

# %%
# !conda install -c conda-forge pynio
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /ncar/usr/jupyterhub.hpc.ucar.edu/jupyterhub-20220511
#
#   added / updated specs:
#     - pynio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blosc-1.21.3               |       hafa529b_0          39 KB  conda-forge
#     boost-cpp-1.78.0           |       h75c5d50_1        17.1 MB  conda-forge
#     cairo-1.16.0               |    ha61ee94_1014         1.5 MB  conda-forge
#     cfitsio-4.2.0              |       hd9d235c_0         828 KB  conda-forge
#     conda-23.1.0               |   py39hf3d152e_0         906 KB  conda-forge
#     cryptography-38.0.4        |   py39h3ccb8fc_0         1.3 MB  conda-forge
#     curl-7.88.1                |       hdc1c0ab_0          86 KB  conda-forge
#     expat-2.5.0                |       h27087fc_0         189 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.2          |       h14ed4e7_0         266 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freeglut-3.2.2             |       h9c3ff4c_1         162 KB  conda-forge
#     freetype-2.12.1            |       hca18f0e_1         611 KB  conda-forge
#     freexl-1.0.6               |       h166bdaf_1          48 KB  conda-forge
#     g2clib-1.6.0               |                3          42 KB  conda-forge
#     geos-3.11.1                |       h27087fc_0         1.6 MB  conda-forge
#     geotiff-1.7.1              |       h7157cca_5         249 KB  conda-forge
#     gettext-0.21.1             |       h27087fc_0         4.1 MB  conda-forge
#     glib-2.74.1                |       h6239696_1         474 KB  conda-forge
#     glib-tools-2.74.1          |       h6239696_1         107 KB  conda-forge
#     hdf4-4.2.15                |       h9772cbc_5         951 KB  conda-forge
#     hdf5-1.12.2                |nompi_h4df4325_101         3.2 MB  conda-forge
#     hdfeos2-2.20               |    hb955811_1002         227 KB  conda-forge
#     hdfeos5-5.1.16             |      hc2f950b_10         562 KB  conda-forge
#     jasper-2.0.33              |       h0ff4b12_1         709 KB  conda-forge
#     json-c-0.16                |       hc379101_0         275 KB  conda-forge
#     kealib-1.5.0               |       ha7026e8_0         160 KB  conda-forge
#     krb5-1.20.1                |       h81ceb04_0         1.3 MB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libaec-1.0.6               |       hcb278e6_1          34 KB  conda-forge
#     libcurl-7.88.1             |       hdc1c0ab_0         350 KB  conda-forge
#     libdap4-3.20.6             |       hd7c4107_2        11.3 MB  conda-forge
#     libdeflate-1.14            |       h166bdaf_0          81 KB  conda-forge
#     libgcc-ng-12.2.0           |      h65d4601_19         931 KB  conda-forge
#     libgdal-3.5.3              |      h05f8703_11        12.0 MB  conda-forge
#     libglib-2.74.1             |       h606061b_1         3.1 MB  conda-forge
#     libglu-9.0.0               |    he1b5a44_1001         413 KB  conda-forge
#     libgomp-12.2.0             |      h65d4601_19         455 KB  conda-forge
#     libiconv-1.17              |       h166bdaf_0         1.4 MB  conda-forge
#     libkml-1.3.0               |    h37653c0_1015         610 KB  conda-forge
#     libnetcdf-4.8.1            |nompi_h261ec11_106         1.5 MB  conda-forge
#     libnghttp2-1.52.0          |       h61bc06f_0         608 KB  conda-forge
#     libpng-1.6.39              |       h753d276_0         276 KB  conda-forge
#     libpq-15.2                 |       hb675445_0         2.3 MB  conda-forge
#     librttopo-1.1.0            |      ha49c73b_12         236 KB  conda-forge
#     libspatialite-5.0.1        |      h7c8129e_22         4.4 MB  conda-forge
#     libsqlite-3.40.0           |       h753d276_0         791 KB  conda-forge
#     libssh2-1.10.0             |       hf14f497_3         234 KB  conda-forge
#     libstdcxx-ng-12.2.0        |      h46fd767_19         4.3 MB  conda-forge
#     libtiff-4.5.0              |       h82bc61c_0         398 KB  conda-forge
#     libwebp-1.2.4              |       h1daa5a0_1          82 KB  conda-forge
#     libwebp-base-1.2.4         |       h5eee18b_1         376 KB
#     libxml2-2.10.3             |       h7463322_0         754 KB  conda-forge
#     libzip-1.9.2               |       hc929e4a_1          97 KB  conda-forge
#     libzlib-1.2.13             |       h166bdaf_4          64 KB  conda-forge
#     nodejs-17.9.0              |       h8839609_0        15.2 MB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     nss-3.89                   |       he45b914_0         1.9 MB  conda-forge
#     openjpeg-2.5.0             |       hfec8fc6_2         344 KB  conda-forge
#     openssl-3.1.0              |       h0b41bf4_0         2.5 MB  conda-forge
#     pcre2-10.40                |       hc3806b6_0         2.3 MB  conda-forge
#     pillow-9.4.0               |   py39h6a678d5_0         727 KB
#     pixman-0.40.0              |       h36c2ea0_0         627 KB  conda-forge
#     poppler-22.12.0            |       h381b16e_0        17.3 MB
#     poppler-data-0.4.12        |       hd8ed1ab_0         2.2 MB  conda-forge
#     postgresql-15.2            |       h3248436_0         4.9 MB  conda-forge
#     proj-9.1.0                 |       h8ffa02c_1         2.7 MB  conda-forge
#     pycurl-7.45.1              |   py39h9297c8b_3          74 KB  conda-forge
#     pynio-1.5.5                |  py39h91e556f_19         5.6 MB  conda-forge
#     python-3.9.16              |h2782a2a_0_cpython        23.0 MB  conda-forge
#     readline-8.1.2             |       h0f457ee_0         291 KB  conda-forge
#     snappy-1.1.10              |       h9fff704_0          38 KB  conda-forge
#     tiledb-2.13.2              |       hd532e3d_0         4.9 MB  conda-forge
#     tzcode-2022g               |       h166bdaf_0          65 KB  conda-forge
#     xerces-c-3.2.4             |       h55805fa_1         1.7 MB  conda-forge
#     xorg-fixesproto-5.0        |    h7f98852_1002           9 KB  conda-forge
#     xorg-inputproto-2.3.2      |    h7f98852_1002          19 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.0.10         |       h7f98852_0          58 KB  conda-forge
#     xorg-libsm-1.2.3           |    hd9c2040_1000          26 KB  conda-forge
#     xorg-libx11-1.8.4          |       h0b41bf4_0         810 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxfixes-5.0.3       |    h7f98852_1004          18 KB  conda-forge
#     xorg-libxi-1.7.10          |       h7f98852_0          46 KB  conda-forge
#     xorg-libxrender-0.9.10     |    h7f98852_1003          32 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h0b41bf4_1003          30 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     zlib-1.2.13                |       h166bdaf_4          92 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       175.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   blosc              conda-forge/linux-64::blosc-1.21.3-hafa529b_0
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.78.0-h75c5d50_1
#   cairo              conda-forge/linux-64::cairo-1.16.0-ha61ee94_1014
#   cfitsio            conda-forge/linux-64::cfitsio-4.2.0-hd9d235c_0
#   expat              conda-forge/linux-64::expat-2.5.0-h27087fc_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freeglut           conda-forge/linux-64::freeglut-3.2.2-h9c3ff4c_1
#   freexl             conda-forge/linux-64::freexl-1.0.6-h166bdaf_1
#   g2clib             conda-forge/linux-64::g2clib-1.6.0-3
#   geos               conda-forge/linux-64::geos-3.11.1-h27087fc_0
#   geotiff            conda-forge/linux-64::geotiff-1.7.1-h7157cca_5
#   glib               conda-forge/linux-64::glib-2.74.1-h6239696_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.74.1-h6239696_1
#   hdf4               conda-forge/linux-64::hdf4-4.2.15-h9772cbc_5
#   hdf5               conda-forge/linux-64::hdf5-1.12.2-nompi_h4df4325_101
#   hdfeos2            conda-forge/linux-64::hdfeos2-2.20-hb955811_1002
#   hdfeos5            conda-forge/linux-64::hdfeos5-5.1.16-hc2f950b_10
#   jasper             conda-forge/linux-64::jasper-2.0.33-h0ff4b12_1
#   json-c             conda-forge/linux-64::json-c-0.16-hc379101_0
#   kealib             conda-forge/linux-64::kealib-1.5.0-ha7026e8_0
#   libaec             conda-forge/linux-64::libaec-1.0.6-hcb278e6_1
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-hd7c4107_2
#   libgdal            conda-forge/linux-64::libgdal-3.5.3-h05f8703_11
#   libglu             conda-forge/linux-64::libglu-9.0.0-he1b5a44_1001
#   libkml             conda-forge/linux-64::libkml-1.3.0-h37653c0_1015
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.8.1-nompi_h261ec11_106
#   libpq              conda-forge/linux-64::libpq-15.2-hb675445_0
#   librttopo          conda-forge/linux-64::librttopo-1.1.0-ha49c73b_12
#   libspatialite      conda-forge/linux-64::libspatialite-5.0.1-h7c8129e_22
#   libsqlite          conda-forge/linux-64::libsqlite-3.40.0-h753d276_0
#   libxml2            conda-forge/linux-64::libxml2-2.10.3-h7463322_0
#   libzip             conda-forge/linux-64::libzip-1.9.2-hc929e4a_1
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.89-he45b914_0
#   pcre2              conda-forge/linux-64::pcre2-10.40-hc3806b6_0
#   pixman             conda-forge/linux-64::pixman-0.40.0-h36c2ea0_0
#   poppler            pkgs/main/linux-64::poppler-22.12.0-h381b16e_0
#   poppler-data       conda-forge/noarch::poppler-data-0.4.12-hd8ed1ab_0
#   postgresql         conda-forge/linux-64::postgresql-15.2-h3248436_0
#   proj               conda-forge/linux-64::proj-9.1.0-h8ffa02c_1
#   pynio              conda-forge/linux-64::pynio-1.5.5-py39h91e556f_19
#   snappy             conda-forge/linux-64::snappy-1.1.10-h9fff704_0
#   tiledb             conda-forge/linux-64::tiledb-2.13.2-hd532e3d_0
#   tzcode             conda-forge/linux-64::tzcode-2022g-h166bdaf_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.4-h55805fa_1
#   xorg-fixesproto    conda-forge/linux-64::xorg-fixesproto-5.0-h7f98852_1002
#   xorg-inputproto    conda-forge/linux-64::xorg-inputproto-2.3.2-h7f98852_1002
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h7f98852_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-hd9c2040_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.4-h0b41bf4_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-5.0.3-h7f98852_1004
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.7.10-h7f98852_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h7f98852_1003
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
# The following packages will be UPDATED:
#
#   conda                              22.11.1-py39hf3d152e_1 --> 23.1.0-py39hf3d152e_0
#   cryptography                        36.0.2-py39hd97740a_1 --> 38.0.4-py39h3ccb8fc_0
#   curl                                    7.83.1-h7bff187_0 --> 7.88.1-hdc1c0ab_0
#   freetype                                2.10.4-h0708190_1 --> 2.12.1-hca18f0e_1
#   gettext                            0.19.8.1-h73d1719_1008 --> 0.21.1-h27087fc_0
#   krb5                                    1.19.3-h3790be6_0 --> 1.20.1-h81ceb04_0
#   lerc                                       3.0-h9c3ff4c_0 --> 4.0.0-h27087fc_0
#   libcurl                                 7.83.1-h7bff187_0 --> 7.88.1-hdc1c0ab_0
#   libdeflate                                1.10-h7f98852_0 --> 1.14-h166bdaf_0
#   libgcc-ng                              11.2.0-h1d223b6_16 --> 12.2.0-h65d4601_19
#   libglib                                 2.70.2-h174f98d_4 --> 2.74.1-h606061b_1
#   libgomp                                11.2.0-h1d223b6_16 --> 12.2.0-h65d4601_19
#   libiconv                                  1.16-h516909a_0 --> 1.17-h166bdaf_0
#   libnghttp2                              1.47.0-h727a467_0 --> 1.52.0-h61bc06f_0
#   libpng                                  1.6.37-h21135ba_2 --> 1.6.39-h753d276_0
#   libssh2                                 1.10.0-ha56f1ee_2 --> 1.10.0-hf14f497_3
#   libstdcxx-ng                           11.2.0-he4da1e4_16 --> 12.2.0-h46fd767_19
#   libtiff                                  4.3.0-h542a066_3 --> 4.5.0-h82bc61c_0
#   libwebp                                  1.2.2-h3452ae3_0 --> 1.2.4-h1daa5a0_1
#   libwebp-base       conda-forge::libwebp-base-1.2.2-h7f98~ --> pkgs/main::libwebp-base-1.2.4-h5eee18b_1
#   libzlib                              1.2.11-h166bdaf_1014 --> 1.2.13-h166bdaf_4
#   openjpeg                                 2.4.0-hb52868f_1 --> 2.5.0-hfec8fc6_2
#   openssl                                 1.1.1o-h166bdaf_0 --> 3.1.0-h0b41bf4_0
#   pillow             conda-forge::pillow-9.1.0-py39hae2aec~ --> pkgs/main::pillow-9.4.0-py39h6a678d5_0
#   pycurl                              7.45.1-py39hd73adbb_1 --> 7.45.1-py39h9297c8b_3
#   python                          3.9.12-h9a8a25e_1_cpython --> 3.9.16-h2782a2a_0_cpython
#   readline                                   8.1-h46c0cb4_0 --> 8.1.2-h0f457ee_0
#   xz                                       5.2.5-h516909a_1 --> 5.2.6-h166bdaf_0
#   zlib                                 1.2.11-h166bdaf_1014 --> 1.2.13-h166bdaf_4
#
# The following packages will be DOWNGRADED:
#
#   nodejs                                  17.9.0-h96d913c_0 --> 17.9.0-h8839609_0
#
#
# Proceed ([y]/n)? ^C

# %%
y
